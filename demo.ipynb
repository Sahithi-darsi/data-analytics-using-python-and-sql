# %%
print("Sahithi")
# Out:
# Sahithi

# %%
import kaggle
https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# Out:
#   Cell In[2], line 2
#     https://www.kaggle.com/datasets/ankitbansal06/retail-orders
#           ^
# SyntaxError: invalid syntax

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kaggle
#       2 get_ipython().system('kaggle datasets download ankitbansal06/retail-orders -f orders.csv')
#
# ModuleNotFoundError: No module named 'kaggle'

# %%
import kaggle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import kaggle
#
# ModuleNotFoundError: No module named 'kaggle'

# %%
import Kaggle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import Kaggle
#
# ModuleNotFoundError: No module named 'Kaggle'

# %%
pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/82.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/82.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/82.1 kB ? eta -:--:--
#      -------------- ----------------------- 30.7/82.1 kB 187.9 kB/s eta 0:00:01
#      -------------------------------------  81.9/82.1 kB 383.3 kB/s eta 0:00:01
#      -------------------------------------  81.9/82.1 kB 383.3 kB/s eta 0:00:01
#      -------------------------------------  81.9/82.1 kB 383.3 kB/s eta 0:00:01
#      -------------------------------------- 82.1/82.1 kB 255.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.14-py3-none-any.whl size=105130 sha256=23e655ee40ef85b92d04cdc9737d2fc01f334e521d831bceb2d2b2c1259e692d
# ...

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import kaggle
#       2 get_ipython().system('kaggle datasets download ankitbansal06/retail-orders -f orders.csv')
#
# File ~\anaconda3\Lib\site-packages\kaggle\__init__.py:7
#       4 from kaggle.api_client import ApiClient
#       6 api = KaggleApi(ApiClient())
# ----> 7 api.authenticate()
#
# File ~\anaconda3\Lib\site-packages\kaggle\api\kaggle_api_extended.py:398, in KaggleApi.authenticate(self)
#     396         return
#     397     else:
# --> 398         raise IOError('Could not find {}. Make sure it\'s located in'
#     399                       ' {}. Or use the environment method.'.format(
#     400                           self.config_file, self.config_dir))
#     402 # Step 3: load into configuration!
#     403 self._load_config(config_data)
#
# ...

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import kaggle
#       2 get_ipython().system('kaggle datasets download ankitbansal06/retail-orders -f orders.csv')
#
# File ~\anaconda3\Lib\site-packages\kaggle\__init__.py:7
#       4 from kaggle.api_client import ApiClient
#       6 api = KaggleApi(ApiClient())
# ----> 7 api.authenticate()
#
# File ~\anaconda3\Lib\site-packages\kaggle\api\kaggle_api_extended.py:398, in KaggleApi.authenticate(self)
#     396         return
#     397     else:
# --> 398         raise IOError('Could not find {}. Make sure it\'s located in'
#     399                       ' {}. Or use the environment method.'.format(
#     400                           self.config_file, self.config_dir))
#     402 # Step 3: load into configuration!
#     403 self._load_config(config_data)
#
# ...

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import kaggle
#       2 get_ipython().system('kaggle datasets download ankitbansal06/retail-orders -f orders.csv')
#
# File ~\anaconda3\Lib\site-packages\kaggle\__init__.py:7
#       4 from kaggle.api_client import ApiClient
#       6 api = KaggleApi(ApiClient())
# ----> 7 api.authenticate()
#
# File ~\anaconda3\Lib\site-packages\kaggle\api\kaggle_api_extended.py:398, in KaggleApi.authenticate(self)
#     396         return
#     397     else:
# --> 398         raise IOError('Could not find {}. Make sure it\'s located in'
#     399                       ' {}. Or use the environment method.'.format(
#     400                           self.config_file, self.config_dir))
#     402 # Step 3: load into configuration!
#     403 self._load_config(config_data)
#
# ...

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 222kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 222kB/s]

# %%
import zipfile
zip_ref=zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df=pd.read_csv('orders')
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('orders')
#       3 df.head(20)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df=pd.read_csv('orders.csv' ,na_values=['Not Available' , 'unknown'])
df.head(20)
df['Ship Mode'].unique()
# Out:
#   Cell In[16], line 2
#     df=pd.read_csv('orders.csv' na_values='Not Available' , 'unknown')
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
df=pd.read_csv('orders.csv')
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13   Not Available     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23   Not Available     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31   Not Available     Consumer  United States
# 11        12  2023-12-25   Not Available     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
import pandas as pd
df=pd.read_csv('orders.csv')
df.head(20)
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
import pandas as pd
df=pd.read_csv('orders.csv',na_values=['Not Available','unknown'])
df.head(20)
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.rename(columns={'Order Id': 'order_id','City':'town'})
# Out:
#       order_id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  town       State  Postal Code Region         Category  \
# ...

# %%
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
df.columns.str.lower()
# Out:
# Index(['order id', 'order date', 'ship mode', 'segment', 'country', 'city',
#        'state', 'postal code', 'region', 'category', 'sub category',
#        'product id', 'cost price', 'list price', 'quantity',
#        'discount percent'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
df.replace(' ','_')
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.head(5)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
import pandas as pd
df=pd.read_csv('orders.csv')
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13   Not Available     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23   Not Available     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31   Not Available     Consumer  United States
# 11        12  2023-12-25   Not Available     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
#derive new column discounts , price and profits

df['discounts']=df['List Price']*df['Discount Percent']*.01
df['sale_price']=df['List Price']-df['discounts']
df['profit']=df['sale_price']-df['cost price']
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
#convert order date from object data type to datetime
df['Order Date']=pd.to_datetime(df['Order Date'],format="%Y-%m-%d")
df
# Out:
#       Order Id Order Date       Ship Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
# drop cost price,list price and discount percent columns
df
# Out:
#       Order Id Order Date       Ship Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#load the data into sql server using replace option
import sqlalchemy as sal
engine = sal.create_engine('mssql://DESKTOP-80M6COB\SQLEXPRESS/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()

# %%
#load the data into sql server using append option
df.to_sql('df_orders', con=conn , index=False , if_exists= 'replace')
# Out:
# 38
